# %%
l = [4,2,2,8,4,9,1]

# %%
m = sorted(l)
m
# Out:
# [1, 2, 2, 4, 4, 8, 9]

# %%
n = len(l)
n
# Out:
# 7

# %%
if n%2 != 0:
    me=m[int((n+1)/2)-1]
else: 
    me = (m[int(n/2)] + m[int((n/2)+1)])/2


me
# Out:
# 4
