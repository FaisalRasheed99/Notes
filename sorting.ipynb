# %%
a = [-20,326,-100,55,426,111,48,99,-76]

# %%
for i in range(len(a)):
    for j in range(len(a)-1):
        if a[i] > a[j]:
            a[i],a[j]=a[j],a[i]

# %%
a
# Out:
# [426, 326, 111, 99, 55, 48, -20, -76, -100]
