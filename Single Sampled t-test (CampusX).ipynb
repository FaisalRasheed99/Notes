# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns

# %%
# load dataset titanic
df = sns.load_dataset('titanic').drop(columns=['survived'])

# %%
df = df['age'].dropna()

# %%
df
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 885    39.0
# 886    27.0
# 887    19.0
# 889    26.0
# 890    32.0
# Name: age, Length: 714, dtype: float64

# %%
sample_age = df.sample(25).values

# %%
sample_age
# Out:
# array([19. , 47. , 27. , 45. , 63. , 21. , 31. , 17. , 36. , 32.5, 22. ,
#        16. , 28.5, 42. ,  4. , 33. , 10. , 54. , 45. , 22. , 51. , 21. ,
#        24. , 54. , 47. ])

# %%
# check for "NORMALITY" using Shapiro Wilk test
from scipy.stats import shapiro

shapiro_age = shapiro(sample_age)

print(shapiro_age)
# Out:
# ShapiroResult(statistic=0.9701368808746338, pvalue=0.648544430732727)

# %%
pop_mean = 35

# %% [markdown]
# H0 : mu = 35 &
# H1 : mu < 35

# %%
import scipy.stats as stats

t_statistic, p_value = stats.ttest_1samp(sample_age, pop_mean)

print("t-statistic:", t_statistic)
print("p-value:", p_value/2)
# Out:
# t-statistic: -0.8210792533094643
# p-value: 0.2098413633398996

# %%
alpha = 0.05

if p_value < alpha:
    print("Reject the null hypothesis.")
else:
    print("Fail to reject the null hypothesis.")
# Out:
# Fail to reject the null hypothesis.
