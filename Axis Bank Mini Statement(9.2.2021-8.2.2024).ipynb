# %%
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\acer'

# %%
cd C:\\Users\\acer\\Downloads
# Out:
# C:\Users\acer\Downloads

# %%
df1 = pd.read_excel("920010072464939.xls")[15:26]
df1 = df1.rename(columns=df1.iloc[0]).drop(df1.index[0]).reset_index(drop=True)
df1
# Out:
#   SRL NO   Tran Date CHQNO                                      PARTICULARS  \
# 0      1  31-03-2021     -  920010072464939:Int.Pd:01-01-2021 to 31-03-2021
# 1      2  18-04-2021     -                               GST @18% on Charge
# 2      3  18-04-2021     -                     Consolidated Charges for A/c
# 3      4  01-07-2021     -  920010072464939:Int.Pd:01-04-2021 to 30-06-2021
# 4      5  18-07-2021     -                               GST @18% on Charge
# 5      6  18-07-2021     -                     Consolidated Charges for A/c
# 6      7  01-10-2021     -  920010072464939:Int.Pd:01-07-2021 to 30-09-2021
# 7      8  30-11-2021     -       ATM-CASH-AXIS/DPCN166408/5664/301121/PATNA
# 8      9  13-12-2021     -          Dr Card Charges ANNUAL 4616XXXXXXXX6139
# 9     10  01-01-2022     -  920010072464939:Int.Pd:01-10-2021 to 31-12-2021
#
#                       DR                     CR                   BAL   SOL
# ...

# %%
df2 = pd.read_excel("920010072464939 (1).xls")[15:45]
df2 = df2.rename(columns=df2.iloc[0]).drop(df2.index[0]).reset_index(drop=True)
df2
# Out:
#    SRL NO   Tran Date CHQNO                                      PARTICULARS  \
# 0       1  13-02-2022     -                               GST @18% on Charge
# 1       2  13-02-2022     -                     Consolidated Charges for A/c
# 2       3  20-03-2022     -                               GST @18% on Charge
# 3       4  20-03-2022     -                     Consolidated Charges for A/c
# 4       5  31-03-2022     -  920010072464939:Int.Pd:01-01-2022 to 31-03-2022
# 5       6  17-04-2022     -                               GST @18% on Charge
# 6       7  17-04-2022     -                     Consolidated Charges for A/c
# 7       8  21-05-2022     -                           GST @18% on MAB Charge
# 8       9  21-05-2022     -                      Monthly Service Fee 05-2022
# 9      10  11-06-2022     -                           GST @18% on MAB Charge
# 10     11  11-06-2022     -                      Monthly Service Fee 06-2022
# ...

# %%
df3 = pd.read_excel("920010072464939 (2).xls")[15:49]
df3 = df3.rename(columns=df3.iloc[0]).drop(df3.index[0]).reset_index(drop=True)
df3
# Out:
#    SRL NO   Tran Date CHQNO  \
# 0       1  10-02-2023     -
# 1       2  10-02-2023     -
# 2       3  11-03-2023     -
# 3       4  11-03-2023     -
# 4       5  31-03-2023     -
# 5       6  12-04-2023     -
# 6       7  12-04-2023     -
# 7       8  13-05-2023     -
# 8       9  13-05-2023     -
# 9      10  09-06-2023     -
# 10     11  09-06-2023     -
# 11     12  01-07-2023     -
# 12     13  18-07-2023     -
# 13     14  18-07-2023     -
# 14     15  18-08-2023     -
# 15     16  18-08-2023     -
# 16     17  09-09-2023     -
# 17     18  09-09-2023     -
# 18     19  01-10-2023     -
# 19     20  11-10-2023     -
# 20     21  11-10-2023     -
# 21     22  11-10-2023     -
# 22     23  18-10-2023     -
# 23     24  01-11-2023     -
# 24     25  25-11-2023     -
# 25     26  25-11-2023     -
# 26     27  27-11-2023     -
# 27     28  27-11-2023     -
# 28     29  30-12-2023     -
# 29     30  30-12-2023     -
# 30     31  01-01-2024     -
# 31     32  21-01-2024     -
# ...

# %%
df = pd.concat([df1,df2,df3]).reset_index()
df
# Out:
#     index SRL NO   Tran Date CHQNO  \
# 0       0      1  31-03-2021     -
# 1       1      2  18-04-2021     -
# 2       2      3  18-04-2021     -
# 3       3      4  01-07-2021     -
# 4       4      5  18-07-2021     -
# ..    ...    ...         ...   ...
# 67     28     29  30-12-2023     -
# 68     29     30  30-12-2023     -
# 69     30     31  01-01-2024     -
# 70     31     32  21-01-2024     -
# 71     32     33  21-01-2024     -
#
#                                           PARTICULARS                     DR  \
# 0     920010072464939:Int.Pd:01-01-2021 to 31-03-2021
# 1                                  GST @18% on Charge                   2.70
# 2                        Consolidated Charges for A/c                  15.00
# 3     920010072464939:Int.Pd:01-04-2021 to 30-06-2021
# 4                                  GST @18% on Charge                   2.70
# ..                                                ...                    ...
# ...

# %%
df['DR'] = pd.to_numeric(df['DR'], errors='coerce')
df['CR'] = pd.to_numeric(df['CR'], errors='coerce')

# %%
df[df['PARTICULARS'].str.contains('Consolidated Charges for A/c')]
# Out:
#     index SRL NO   Tran Date CHQNO                   PARTICULARS     DR  CR  \
# 2       2      3  18-04-2021     -  Consolidated Charges for A/c   15.0 NaN
# 5       5      6  18-07-2021     -  Consolidated Charges for A/c   15.0 NaN
# 11      1      2  13-02-2022     -  Consolidated Charges for A/c  106.5 NaN
# 13      3      4  20-03-2022     -  Consolidated Charges for A/c  113.1 NaN
# 16      6      7  17-04-2022     -  Consolidated Charges for A/c  116.7 NaN
#
#                      BAL   SOL
# 2               14529.40  2854
# 5               14620.70  2854
# 11               9113.03  2854
# 13               8979.57  2854
# 16               8909.86  2854

# %%
df[df['PARTICULARS'].str.contains('Consolidated Charges for A/c')]['DR'].sum()
# Out:
# 366.3

# %%
df[df['PARTICULARS'].str.contains('Dr Card Charges')]
# Out:
#     index SRL NO   Tran Date CHQNO                              PARTICULARS  \
# 8       8      9  13-12-2021     -  Dr Card Charges ANNUAL 4616XXXXXXXX6139
# 33     23     24  06-12-2022     -  Dr Card Charges ANNUAL 4616XXXXXXXX6139
# 62     23     24  01-11-2023     -   Dr Card Charges ISSUE 4364XXXXXXXX2983
#
#         DR  CR                   BAL   SOL
# 8    590.0 NaN               9141.70  2854
# 33   590.0 NaN               6436.73  2854
# 62  1770.0 NaN                 44.79  2854

# %%
df[df['PARTICULARS'].str.contains('Dr Card Charges')]['DR'].sum()
# Out:
# 2950.0

# %%
df[df['PARTICULARS'].str.contains(':Int.Pd:')]
# Out:
#     index SRL NO   Tran Date CHQNO  \
# 0       0      1  31-03-2021     -
# 3       3      4  01-07-2021     -
# 6       6      7  01-10-2021     -
# 9       9     10  01-01-2022     -
# 14      4      5  31-03-2022     -
# 21     11     12  01-07-2022     -
# 28     18     19  01-10-2022     -
# 36     26     27  01-01-2023     -
# 43      4      5  31-03-2023     -
# 50     11     12  01-07-2023     -
# 57     18     19  01-10-2023     -
# 69     30     31  01-01-2024     -
#
#                                         PARTICULARS  DR     CR  \
# 0   920010072464939:Int.Pd:01-01-2021 to 31-03-2021 NaN  107.0
# 3   920010072464939:Int.Pd:01-04-2021 to 30-06-2021 NaN  109.0
# 6   920010072464939:Int.Pd:01-07-2021 to 30-09-2021 NaN  111.0
# 9   920010072464939:Int.Pd:01-10-2021 to 31-12-2021 NaN   97.0
# 14  920010072464939:Int.Pd:01-01-2022 to 31-03-2022 NaN   68.0
# 21  920010072464939:Int.Pd:01-04-2022 to 30-06-2022 NaN   66.0
# ...

# %%
df[df['PARTICULARS'].str.contains(':Int.Pd:')]["CR"].sum()
# Out:
# 758.0

# %%
df[df['PARTICULARS'].str.contains('Non-Maint Avg bal chgs')]
# Out:
#     index SRL NO   Tran Date CHQNO                     PARTICULARS      DR  \
# 40      1      2  10-02-2023     -  Non-Maint Avg bal chgs Dec2022  432.23
# 42      3      4  11-03-2023     -  Non-Maint Avg bal chgs Jan2023  464.78
# 45      6      7  12-04-2023     -  Non-Maint Avg bal chgs Feb2023  501.08
# 47      8      9  13-05-2023     -  Non-Maint Avg bal chgs Mar2023  541.13
# 49     10     11  09-06-2023     -  Non-Maint Avg bal chgs Apr2023  463.74
# 52     13     14  18-07-2023     -  Non-Maint Avg bal chgs May2023  500.22
# 54     15     16  18-08-2023     -  Non-Maint Avg bal chgs Jun2023  539.04
# 56     17     18  09-09-2023     -  Non-Maint Avg bal chgs Jul2023  562.26
# 60     21     22  11-10-2023     -  Non-Maint Avg bal chgs Aug2023  598.92
# 66     27     28  27-11-2023     -  Non-Maint Avg bal chgs Sep2023   58.43
#
#     CR                   BAL   SOL
# 40 NaN               5155.77  2854
# 42 NaN               4607.33  2854
# 45 NaN               4055.06  2854
# ...

# %%
df[df['PARTICULARS'].str.contains('Non-Maint Avg bal chgs')]["DR"].sum()
# Out:
# 4661.830000000001

# %%
df[df['PARTICULARS'].str.contains('Monthly Service Fee')]
# Out:
#     index SRL NO   Tran Date CHQNO                  PARTICULARS      DR  CR  \
# 18      8      9  21-05-2022     -  Monthly Service Fee 05-2022  121.85 NaN
# 20     10     11  11-06-2022     -  Monthly Service Fee 06-2022  225.85 NaN
# 23     13     14  16-07-2022     -  Monthly Service Fee 07-2022  232.10 NaN
# 25     15     16  20-08-2022     -  Monthly Service Fee 08-2022  255.90 NaN
# 27     17     18  15-09-2022     -  Monthly Service Fee 09-2022  268.20 NaN
# 30     20     21  12-10-2022     -  Monthly Service Fee 10-2022  286.95 NaN
# 32     22     23  13-11-2022     -  Monthly Service Fee 11-2022  313.50 NaN
# 35     25     26  09-12-2022     -  Monthly Service Fee 12-2022  336.30 NaN
# 37     27     28  11-01-2023     -  Monthly Service Fee 01-2023  361.95 NaN
#
#                      BAL   SOL
# 18               8766.08  2854
# 20               8499.58  2854
# 23               8291.70  2854
# 25               7989.74  2854
# 27               7673.26  2854
# ...

# %%
df[df['PARTICULARS'].str.contains('Monthly Service Fee')]["DR"].sum()
# Out:
# 2402.6

# %%
df.to_excel("Axis Bank Mini Statement.xlsx")
