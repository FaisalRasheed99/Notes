# %%
l = [2,4,1,7,3,9,8]
l2 = [1,1,4,3,7,6,9]
l.extend(l2)
l
# Out:
# [2, 4, 1, 7, 3, 9, 8, 1, 1, 4, 3, 7, 6, 9]

# %%
l = [2,4,1,7,3,9,8]
l2 = [1,1,4,3,7,6,9]
l.append(l2)
l
# Out:
# [2, 4, 1, 7, 3, 9, 8, [1, 1, 4, 3, 7, 6, 9]]

# %%
def flatten_list(nested_list):
    flat_list = []
    for item in nested_list:
        if isinstance(item, list):
            flat_list.extend(flatten_list(item))
        else:
            flat_list.append(item)
    return flat_list

nested_list = [2, 4, 1, 7, 3, 9, 8, [1, 1, 4, 3, 7, 6, 9]]
flatten_list(nested_list)
# Out:
# [2, 4, 1, 7, 3, 9, 8, 1, 1, 4, 3, 7, 6, 9]

# %%
d = {1:3,4:3,6:9,5:6,7:0}
import pandas as pd
pd.DataFrame(list(d.items()))
# Out:
#    0  1
# 0  1  3
# 1  4  3
# 2  6  9
# 3  5  6
# 4  7  0
