# %%
#pip install openai

# %%
#setx OPENAI_API_KEY "your_api_key_here"

# %%
import openai
client = openai.OpenAI(api_key = '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')
completion = client.chat.completions.create(
model="gpt-3.5-turbo",
messages=[
{"role": "system", "content": "You are a poetic assistant, skilled in explaining complex programming concepts with creative flair."},
{"role": "user", "content": "Compose a poem that explains the concept of recursion in programming."}
]
)

print(completion.choices[0].message)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[3], line 3
#       1 import openai
#       2 client = openai.OpenAI(api_key = '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')
# ----> 3 completion = client.chat.completions.create(
#       4 model="gpt-3.5-turbo",
#       5 messages=[
#       6 {"role": "system", "content": "You are a poetic assistant, skilled in explaining complex programming concepts with creative flair."},
#       7 {"role": "user", "content": "Compose a poem that explains the concept of recursion in programming."}
#       8 ]
#       9 )
#      11 print(completion.choices[0].message)
#
# File ~\anaconda3\Lib\site-packages\openai\_utils\_utils.py:274, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
# ...

# %%
completion = client. chat. completions. create(
model="gpt-3.5-turbo",
messages=[
{"role": "user", "content": "Compose a poem that explains the concept of recursion in programming."}

]

)

print(completion.choices[0].message)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 completion = client. chat. completions. create(
#       2 model="gpt-3.5-turbo",
#       3 messages=[
#       4 {"role": "user", "content": "Compose a poem that explains the concept of recursion in programming."}
#       5
#       6 ]
#       7
#       8 )
#      10 print(completion.choices[0].message)
#
# File ~\anaconda3\Lib\site-packages\openai\_utils\_utils.py:274, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     272             msg = f"Missing required argument: {quote(missing[0])}"
#     273     raise TypeError(msg)
# --> 274 return func(*args, **kwargs)
#
# ...

# %%
from openai import OpenAI
client = OpenAI()

completion = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {
            "role": "user",
            "content": "Write a haiku about recursion in programming."
        }
    ]
)

print(completion.choices[0].message)

# %%
from transformers import pipeline
# Out:
# WARNING:tensorflow:From C:\Users\acer\anaconda3\Lib\site-packages\tensorflow_probability\python\internal\assert_util.py:27: The name tf.assert_equal is deprecated. Please use tf.compat.v1.assert_equal instead.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\transformers\utils\import_utils.py:1130, in _LazyModule._get_module(self, module_name)
#    1129 try:
# -> 1130     return importlib.import_module("." + module_name, self.__name__)
#    1131 except Exception as e:
#
# File ~\anaconda3\Lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# ...

# %%
generator = pipeline('text-generation', 'gpt2')

prompt = "Once upon a time in a faraway land,"

generator(prompt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 generator = pipeline('text-generation', 'gpt2')
#       3 prompt = "Once upon a time in a faraway land,"
#       5 generator(prompt)
#
# NameError: name 'pipeline' is not defined

# %%
generator(prompt,max_length = 100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 generator(prompt,max_length = 100)
#
# NameError: name 'generator' is not defined

# %%
from transformers import BertTokenizer, BertModel #petrained model

tokenizer = BertTokenizer.from_pretrained('google-bert/bert-base-uncased')



model = BertModel.from_pretrained('google-bert/bert-base-uncased' )

tokens = tokenizer('It is a good day. I am going to head out today. ', return_tensors='pt')

tokens
# Out:
# C:\Users\acer\anaconda3\Lib\site-packages\transformers\utils\generic.py:260: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(
# ...
# C:\Users\acer\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:133: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\acer\.cache\huggingface\hub. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# ...

# %%
tokens["input_ids"]
# Out:
# tensor([[ 101, 2009, 2003, 1037, 2204, 2154, 1012, 1045, 2572, 2183, 2000, 2132,
#          2041, 2651, 1012,  102]])

# %%
from transformers import BertTokenizer, BertModel
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained("bert-base-uncased")
text = "Replace me by any text you'd like."
encoded_input = tokenizer(text, return_tensors='pt')
output = model( ** encoded_input)

# %%
output
# Out:
# BaseModelOutputWithPoolingAndCrossAttentions(last_hidden_state=tensor([[[ 0.1386,  0.1583, -0.2967,  ..., -0.2708, -0.2844,  0.4581],
#          [ 0.5364, -0.2327,  0.1754,  ...,  0.5540,  0.4981, -0.0024],
#          [ 0.3002, -0.3475,  0.1208,  ..., -0.4562,  0.3288,  0.8773],
#          ...,
#          [ 0.3799,  0.1203,  0.8283,  ..., -0.8624, -0.5957,  0.0471],
#          [-0.0252, -0.7177, -0.6950,  ...,  0.0757, -0.6668, -0.3401],
#          [ 0.7535,  0.2391,  0.0717,  ...,  0.2467, -0.6458, -0.3213]]],
#        grad_fn=<NativeLayerNormBackward0>), pooler_output=tensor([[-0.9377, -0.5043, -0.9799,  0.9030,  0.9329, -0.2438,  0.8926,  0.2288,
#          -0.9531, -1.0000, -0.8862,  0.9906,  0.9855,  0.7155,  0.9455, -0.8645,
#          -0.6035, -0.6666,  0.3020, -0.1587,  0.7455,  1.0000, -0.4022,  0.4261,
#           0.6151,  0.9996, -0.8773,  0.9594,  0.9585,  0.6950, -0.6718,  0.3325,
#          -0.9954, -0.2268, -0.9658, -0.9951,  0.6127, -0.7670,  0.0873,  0.0824,
# ...

# %%
output["last_hidden_state"].shape
# Out:
# torch.Size([1, 12, 768])

# %%
output.pooler_output.shape
# Out:
# torch.Size([1, 768])

# %%
from transformers import pipeline
unmasker = pipeline('fill-mask', model='bert-base-uncased')
unmasker("Hello I'm a [MASK] model.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\transformers\utils\import_utils.py:1130, in _LazyModule._get_module(self, module_name)
#    1129 try:
# -> 1130     return importlib.import_module("." + module_name, self.__name__)
#    1131 except Exception as e:
#
# File ~\anaconda3\Lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1147, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:940, in exec_module(self, module)
#
# ...

# %%
from transformers import pipeline

translator = pipeline("translation_en_to_fr", "google-t5/t5-base")
translation = translator("What's your name?")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\transformers\utils\import_utils.py:1130, in _LazyModule._get_module(self, module_name)
#    1129 try:
# -> 1130     return importlib.import_module("." + module_name, self.__name__)
#    1131 except Exception as e:
#
# File ~\anaconda3\Lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1147, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:940, in exec_module(self, module)
#
# ...

# %%
from transformers import pipeline

qa_pipeline = pipeline("question-answering")
query = "What is my place of residence?"
qa_result = qa_pipeline(question=query, context='I live in Mumbai')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\transformers\utils\import_utils.py:1130, in _LazyModule._get_module(self, module_name)
#    1129 try:
# -> 1130     return importlib.import_module("." + module_name, self.__name__)
#    1131 except Exception as e:
#
# File ~\anaconda3\Lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1147, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:940, in exec_module(self, module)
#
# ...

# %%
from transformers import pipeline
chosen_model = "distilbert-base-uncased-finetuned-sst-2-english"
distil_bert = pipeline(task="sentiment-analysis", model=chosen_model)

distil_bert('What a great movie!')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\transformers\utils\import_utils.py:1130, in _LazyModule._get_module(self, module_name)
#    1129 try:
# -> 1130     return importlib.import_module("." + module_name, self.__name__)
#    1131 except Exception as e:
#
# File ~\anaconda3\Lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1147, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:940, in exec_module(self, module)
#
# ...

# %%
from transformers import pipeline

qa_pipeline = pipeline("question-answering", "deepset/roberta-base-squad2")
query = "What is quantum physics?"
qa_result = qa_pipeline(question query)
# Out:
#   Cell In[16], line 5
#     qa result qa pipeline(question query)
#        ^
# SyntaxError: invalid syntax

# %%
from transformers import pipeline

translator= pipeline("translation_en_to_fr")
translation = translator("What's your name?")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\transformers\utils\import_utils.py:1130, in _LazyModule._get_module(self, module_name)
#    1129 try:
# -> 1130     return importlib.import_module("." + module_name, self.__name__)
#    1131 except Exception as e:
#
# File ~\anaconda3\Lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1147, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:940, in exec_module(self, module)
#
# ...
