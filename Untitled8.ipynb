# %%
import pandas as pd

# %%
cd Downloads
# Out:
# C:\Users\acer\Downloads

# %%
df = pd.read_csv("2024-10-06-windows-export.csv")

# %%
df
# Out:
#                 sessionId                    session              windowId  \
# 0    P3rfvtCx79jOKbmiwA2U  windows-export 2024-10-06  k3tBL6BTLdoNjCawsyqA
# 1    P3rfvtCx79jOKbmiwA2U  windows-export 2024-10-06  k3tBL6BTLdoNjCawsyqA
# 2    P3rfvtCx79jOKbmiwA2U  windows-export 2024-10-06  k3tBL6BTLdoNjCawsyqA
# 3    P3rfvtCx79jOKbmiwA2U  windows-export 2024-10-06  k3tBL6BTLdoNjCawsyqA
# 4    P3rfvtCx79jOKbmiwA2U  windows-export 2024-10-06  k3tBL6BTLdoNjCawsyqA
# ..                    ...                        ...                   ...
# 215  P3rfvtCx79jOKbmiwA2U  windows-export 2024-10-06  k3tBL6BTLdoNjCawsyqA
# 216  P3rfvtCx79jOKbmiwA2U  windows-export 2024-10-06  k3tBL6BTLdoNjCawsyqA
# 217  P3rfvtCx79jOKbmiwA2U  windows-export 2024-10-06  k3tBL6BTLdoNjCawsyqA
# 218  P3rfvtCx79jOKbmiwA2U  windows-export 2024-10-06  k3tBL6BTLdoNjCawsyqA
# 219  P3rfvtCx79jOKbmiwA2U  windows-export 2024-10-06  k3tBL6BTLdoNjCawsyqA
#
#                 window  height  width  \
# ...

# %%
df=df[::-1]

# %%
df = df.sort_values('url')

# %%
df
# Out:
#                 sessionId                    session              windowId  \
# 219  P3rfvtCx79jOKbmiwA2U  windows-export 2024-10-06  k3tBL6BTLdoNjCawsyqA
# 218  P3rfvtCx79jOKbmiwA2U  windows-export 2024-10-06  k3tBL6BTLdoNjCawsyqA
# 217  P3rfvtCx79jOKbmiwA2U  windows-export 2024-10-06  k3tBL6BTLdoNjCawsyqA
# 216  P3rfvtCx79jOKbmiwA2U  windows-export 2024-10-06  k3tBL6BTLdoNjCawsyqA
# 215  P3rfvtCx79jOKbmiwA2U  windows-export 2024-10-06  k3tBL6BTLdoNjCawsyqA
# ..                    ...                        ...                   ...
# 4    P3rfvtCx79jOKbmiwA2U  windows-export 2024-10-06  k3tBL6BTLdoNjCawsyqA
# 3    P3rfvtCx79jOKbmiwA2U  windows-export 2024-10-06  k3tBL6BTLdoNjCawsyqA
# 2    P3rfvtCx79jOKbmiwA2U  windows-export 2024-10-06  k3tBL6BTLdoNjCawsyqA
# 1    P3rfvtCx79jOKbmiwA2U  windows-export 2024-10-06  k3tBL6BTLdoNjCawsyqA
# 0    P3rfvtCx79jOKbmiwA2U  windows-export 2024-10-06  k3tBL6BTLdoNjCawsyqA
#
#                 window  height  width  \
# ...

# %%
df.to_csv("2024-10-06-windows-export.csv")
