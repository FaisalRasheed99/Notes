# %%
class ClassA:
    var1 = 20
    var2 = 30
    def __init__(mywish):
        mywish.var1 = 100
        mywish.var2 = 100
 
    def methodA(mywish):
        ClassA.var1 = ClassA.var1 + ClassA.var2
        ClassA.var1 = 100000
        return ClassA.var1
 
class ClassB(ClassA):
    def __init__(mywish):
        print(ClassA.var1)
        print (ClassA.var2)

# %%
object1 = ClassA()
sum = object1.methodA()
object2 = ClassB()
print(object1.var1)
print(object1.var2)
print(sum)
# Out:
# 100000
# 30
# 100
# 100
# 100000
