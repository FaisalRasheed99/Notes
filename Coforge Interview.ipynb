# %%
import pandas as pd

# %%
df = pd.read_csv("Pokemon.csv")

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
train= df[:80*7]
train
# Out:
#        #                   Name Type 1    Type 2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison    318   45      49       49
# 1      2                Ivysaur  Grass    Poison    405   60      62       63
# 2      3               Venusaur  Grass    Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison    625   80     100      123
# 4      4             Charmander   Fire       NaN    309   39      52       43
# ..   ...                    ...    ...       ...    ...  ...     ...      ...
# 555  496                Servine  Grass       NaN    413   60      60       75
# 556  497              Serperior  Grass       NaN    528   75      75       95
# 557  498                  Tepig   Fire       NaN    308   65      63       45
# 558  499                Pignite   Fire  Fighting    418   90      93       55
# 559  500                 Emboar   Fire  Fighting    528  110     123       65
#
# ...

# %%
test = df[80*7:]
test
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 560  501             Oshawott    Water    NaN    308  55      55       45
# 561  502               Dewott    Water    NaN    413  75      75       60
# 562  503             Samurott    Water    NaN    528  95     100       85
# 563  504               Patrat   Normal    NaN    255  45      55       39
# 564  505              Watchog   Normal    NaN    420  60      85       69
# ..   ...                  ...      ...    ...    ...  ..     ...      ...
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x1,x2 = train_test_split(df,test_size= 0.3,random_state=1)

# %%
x1
# Out:
#        #                Name    Type 1    Type 2  Total   HP  Attack  Defense  \
# 88    81           Magnemite  Electric     Steel    325   25      35       70
# 107   99             Kingler     Water       NaN    475   55     130      115
# 17    14              Kakuna       Bug    Poison    205   45      25       50
# 700  639           Terrakion      Rock  Fighting    580   91     129       90
# 172  158            Totodile     Water       NaN    314   50      65       64
# ..   ...                 ...       ...       ...    ...  ...     ...      ...
# 715  648  MeloettaAria Forme    Normal   Psychic    600  100      77       77
# 767  697           Tyrantrum      Rock    Dragon    521   82     121      119
# 72    66              Machop  Fighting       NaN    305   70      80       50
# 235  217            Ursaring    Normal       NaN    500   90     130       75
# 37    32            Nidoran♂    Poison       NaN    273   46      57       40
#
# ...

# %%
x2
# Out:
#        #                 Name    Type 1    Type 2  Total   HP  Attack  \
# 745  677               Espurr   Psychic       NaN    355   62      48
# 115  107           Hitmonchan  Fighting       NaN    455   50     105
# 173  159             Croconaw     Water       NaN    405   65      80
# 120  112               Rhydon    Ground      Rock    485  105     130
# 797  720  HoopaHoopa Confined   Psychic     Ghost    600   80     110
# ..   ...                  ...       ...       ...    ...  ...     ...
# 277  256            Combusken      Fire  Fighting    405   60      85
# 591  531    AudinoMega Audino    Normal     Fairy    545  103      60
# 167  153              Bayleef     Grass       NaN    405   60      62
# 707  644               Zekrom    Dragon  Electric    680  100     150
# 765  695            Heliolisk  Electric    Normal    481   62      55
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 745       54       63       60     68           6      False
# ...
